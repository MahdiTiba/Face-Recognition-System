# %% [markdown]
# ### Requirement Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import resnet
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import ReduceLROnPlateau
import shutil
import cv2
import os
import PIL
import random
from mtcnn.mtcnn import MTCNN

# %% [markdown]
# ### Build pair of images dataset

# %%
def images_to_array(root_path, img_target_size=(300, 300), numeric_labels=True):
    """
    read images from directories as a numpy array.
    
    :param root_path(str): root path refering to the path containing sub-folders
    :param img_target_size(tuple): a tuple with size(W, L) to convert image sizes
    :param numeric_labels: if true, output labels will be int. if false, the folder names considered as label
    :return img_array: a numpy array containing all image with shape (#images, img_target_size, #channels)
    """
    img_list = []
    label_list = []
    class_names = os.listdir(root_path)
    #class_names = [str(i) for i in sorted([int(j) for j in os.listdir(root_path)])]
    for i, class_name in enumerate(class_names):
        img_names = os.listdir(os.path.join(root_path, class_name))

        for img_name in img_names:
            path = os.path.join(root_path, class_name, img_name)
            img = cv2.imread(path)
            img = cv2.resize(img, img_target_size)
            img_list.append(img)
            if numeric_labels:
                label_list.append(i)
            else:
                label_list.append(class_name)
        
    img_array = np.array(img_list)
    label_array = np.array(label_list)
    
    return img_array, label_array

# %%
root_path = 'C:\\Users\Lenovo\Documents\Github\Datasets\Facial-Emotion-Recognition\\Data'
img_array, label_array = images_to_array(root_path)
print(f'img_array.shape : {img_array.shape}')
print(f'label_array.shape : {label_array.shape}')

# %%
def make_pairs(images, labels):
    # initialize two empty lists to hold the (image, image) pairs and
    # labels to indicate if a pair is positive or negative
    pair_images = []
    pair_labels = []
    
    # calculate the total number of classes present in the dataset
    # and then build a list of indexes for each class label that
    # provides the indexes for all examples with a given label
    num_classes = len(np.unique(labels))
    idx = [np.where(labels == i)[0] for i in range(0, num_classes)] 
    
    # loop over all images
    for idxA in range(len(images)):
        # grab the current image and label belonging to the current
        # iteration
        current_image = images[idxA]
        label = labels[idxA]
        
        # randomly pick an image that belongs to the *same* class
        # label
        idxB = np.random.choice(idx[label])
        pos_image = images[idxB]
        
        # prepare a positive pair and update the images and labels
        # lists, respectively
        pair_images.append([current_image, pos_image])
        pair_labels.append([1])
        
        # grab the indices for each of the class labels *not* equal to
        # the current label and randomly pick an image corresponding
        # to a label *not* equal to the current label
        negIdx = np.where(labels != label)[0]
        neg_image = images[np.random.choice(negIdx)]
        
        # prepare a negative pair of images and update our lists
        pair_images.append([current_image, neg_image])
        pair_labels.append([0])
        
    # return a 2-tuple of our image pairs and labels
    return (np.array(pair_images), np.array(pair_labels))

# %%
pair_images, pair_labels = make_pairs(img_array, label_array)
print(f'pair_images : {pair_images.shape}')
print(f'pair_labels : {pair_labels.shape}')

# %% [markdown]
# ### define path

# %%
TRAIN_DATASET = 'C:\\Users\\Lenovo\\Documents\\Github\\Datasets\\LFW-edited-copy\\LFW-edited-train'
TEST_DATASET = 'C:\\Users\\Lenovo\\Documents\\Github\\Datasets\\LFW-edited-copy\\LFW-edited-test'

# %% [markdown]
# ### Create test split

# %%
def create_test_split(datasetPath, test_dataset_destination, threshold=300):
    
    person_names_list = os.listdir(datasetPath)
    random.shuffle(person_names_list)
    cnt = 0                              
    for person_name in person_names_list:
        
        absolute_person_folder = os.path.join(datasetPath, person_name)
        
        if cnt == threshold:
            print('-'*20)
            print(f'Stop in {cnt}')
            break
        
        if len(os.listdir(absolute_person_folder)) >= 2:
            print(f'{person_name} - Len:{len(os.listdir(absolute_person_folder))}')
            shutil.move(absolute_person_folder, test_dataset_destination)
            cnt += 1

# %%
create_test_split(TRAIN_DATASET, TEST_DATASET, threshold=300)
# Out:
# Tim_Robbins - Len:5
# Elton_John - Len:7
# Jean-Claude_Juncker - Len:2
# Lindsay_Benko - Len:2
# Melissa_Etheridge - Len:2
# Lionel_Richie - Len:2
# David_Beckham - Len:30
# Cameron_Diaz - Len:6
# Robby_Ginepri - Len:2
# Colin_Montgomerie - Len:4
# Hitomi_Soga - Len:5
# Robert_Kocharian - Len:5
# Paul_Byrd - Len:2
# Kurt_Busch - Len:2
# William_Burns - Len:2
# Will_Smith - Len:2
# Justine_Henin - Len:3
# Johnny_Depp - Len:2
# Marissa_Jaret_Winokur - Len:2
# Martin_Scorsese - Len:6
# Hilary_Duff - Len:3
# David_Hyde_Pierce - Len:4
# Michelle_Rodriguez - Len:2
# Rudolph_Giuliani - Len:25
# Prince_Willem-Alexander - Len:3
# Morgan_Freeman - Len:2
# Richard_Myers - Len:17
# Fidel_Castro - Len:18
# Jeff_Van_Gundy - Len:3
# Richard_Branson - Len:2
# Courtney_Love - Len:2
# Eduardo_Duhalde - Len:14
# Alex_Barros - Len:2
# Marc_Grossman - Len:4
# Silvio_Fernandez - Len:2
# Hilmi_Ozkok - Len:2
# Sheila_Fraser - Len:2
# Hans_Blix - Len:39
# Terrell_Suggs - Len:2
# Margaret_Thatcher - Len:2
# Jane_Fonda - Len:2
# Lars_Von_Trier - Len:3
# Susie_Castillo - Len:2
# Tony_Curtis - Len:2
# Lloyd_Ward - Len:2
# Michael_Chiklis - Len:5
# Fred_Thompson - Len:3
# Ricardo_Lagos - Len:27
# Daisy_Fuentes - Len:4
# Claire_Hentzen - Len:2
# Theodore_Tweed_Roosevelt - Len:3
# Nathalie_Baye - Len:4
# Mike_Krzyzewski - Len:6
# Mike_Weir - Len:10
# Milo_Djukanovic - Len:3
# Robbie_Fowler - Len:2
# Demi_Moore - Len:3
# Goran_Persson - Len:2
# Emmanuelle_Beart - Len:3
# Gil_de_Ferran - Len:5
# Rick_Perry - Len:6
# John_Snow - Len:17
# Rick_Barnes - Len:3
# Julio_Iglesias_Jr - Len:2
# Sarah_Michelle_Gellar - Len:3
# Bobby_Goldwater - Len:2
# Romano_Prodi - Len:7
# Michael_J_Sheehan - Len:2
# Robert_Redford - Len:7
# Christine_Gregoire - Len:4
# Sam_Bith - Len:3
# James_McGreevey - Len:4
# Yuri_Malenchenko - Len:2
# Dennis_Powell - Len:2
# John_Abizaid - Len:9
# Katherine_Harris - Len:4
# Gregg_Popovich - Len:5
# Jean-Claude_Braquet - Len:2
# Scott_Sullivan - Len:2
# Anneli_Jaatteenmaki - Len:2
# Stephen_Daldry - Len:2
# Fran_Drescher - Len:2
# Raghad_Saddam_Hussein - Len:2
# Jennifer_Aniston - Len:21
# Dan_Wheldon - Len:2
# Jonathan_Mostow - Len:2
# Catherine_Deneuve - Len:5
# Andre_Agassi - Len:35
# Kiki_Vandeweghe - Len:2
# Shaukat_Aziz - Len:2
# Jan-Michael_Gambill - Len:3
# Marcelo_Ebrard - Len:3
# Larry_Johnson - Len:2
# Jose_Dirceu - Len:2
# Dominique_de_Villepin - Len:13
# Cherie_Blair - Len:4
# Igor_Ivanov - Len:20
# Meghann_Shaughnessy - Len:2
# Alejandro_Avila - Len:3
# Jake_Gyllenhaal - Len:5
# Brad_Johnson - Len:5
# Phan_Van_Khai - Len:3
# Mark_Heller - Len:2
# Lynne_Cheney - Len:3
# Francisco_Flores - Len:4
# Bob_Hope - Len:8
# --------------------
# Stop in 300

# %% [markdown]
# ### Build triplet images dataset

# %%
class MapFunction():
    def __init__(self, imageSize):
        # define the image width and height
        self.imageSize = imageSize
    def decode_and_resize(self, imagePath):
        # read and decode the image path
        image = tf.io.read_file(imagePath)
        image = tf.image.decode_jpeg(image, channels=3)
        # convert the image data type from uint8 to float32 and then resize
        # the image to the set image size
        image = tf.image.convert_image_dtype(image, dtype=tf.float32)
        image = tf.image.resize(image, self.imageSize)
        # return the image
        return image
    def __call__(self, anchor, positive, negative):
        anchor = self.decode_and_resize(anchor)
        positive = self.decode_and_resize(positive)
        negative = self.decode_and_resize(negative)
        # return the anchor, positive and negative processed images
        return (anchor, positive, negative)

# %%
class TripletGenerator:
    def __init__(self, datasetPath):
        # create an empty list which will contain the subdirectory
        # names of the `dataset` directory with more than one image
        # in it
        self.peopleNames = list()
        # iterate over the subdirectories in the dataset directory
        for folderName in os.listdir(datasetPath):
            # build the subdirectory name
            absoluteFolderName = os.path.join(datasetPath, folderName)
            # get the number of images in the subdirectory
            numImages = len(os.listdir(absoluteFolderName))
            # if the number of images in the current subdirectory
            # is more than one, append into the `peopleNames` list
            if numImages > 1:
                self.peopleNames.append(absoluteFolderName)
        print(f'{len(self.peopleNames)} folders have more than 1 image')
        print('----------------------------')
        
        # create a dictionary of people name to their image names
        self.allPeople = self.generate_all_people_dict()
    def generate_all_people_dict(self):
        # create an empty dictionary that will be populated with
        # directory names as keys and image names as values
        allPeople = dict()
        # iterate over all the directory names with more than one
        # image in it
        for personName in self.peopleNames:
            # get all the image names in the current directory
            imageNames = os.listdir(personName)
            # build the image paths and populate the dictionary
            personPhotos = [
                os.path.join(personName, imageName) for imageName in imageNames
            ]
            allPeople[personName] = personPhotos
        # return the dictionary
        return allPeople
    def get_next_element(self):
        # create an infinite generator
        while True:
            # draw a person at random which will be our anchor and
            # positive person
            anchorName = random.choice(self.peopleNames)
            # copy the list of people names and remove the anchor
            # from the list
            temporaryNames = self.peopleNames.copy()
            temporaryNames.remove(anchorName)
            # draw a person at random from the list of people without
            # the anchor, which will act as our negative sample
            negativeName = random.choice(temporaryNames)
            # draw two images from the anchor folder without replacement
            (anchorPhoto, positivePhoto) = np.random.choice(
                a=self.allPeople[anchorName],
                size=2,
                replace=False
            )
            # draw an image from the negative folder
            negativePhoto = random.choice(self.allPeople[negativeName])
            # yield the anchor, positive and negative photos
            yield (anchorPhoto, positivePhoto, negativePhoto)

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 64
BUFFER_SIZE = BATCH_SIZE * 2
# define autotune
AUTO = tf.data.AUTOTUNE

LEARNING_RATE = 0.001
STEPS_PER_EPOCH = 30
VALIDATION_STEPS = 30
EPOCHS = 100

# %% [markdown]
# ### Create detected face dataset

# %%
# extract a single face from a given photograph
def extract_face(img_path, required_size=(160, 160)):
    # load image from file
    image = cv2.imread(img_path)
    
    detector = MTCNN()
    # detect faces in the image
    results = detector.detect_faces(image)
    
    if len(results) < 1:
        return None
    # extract the bounding box from the first face
    x1, y1, width, height = results[0]['box']
    # deal with negative pixel index
    x1, y1 = abs(x1), abs(y1)
    x2, y2 = x1 + width, y1 + height
    # extract the face
    face = image[y1:y2, x1:x2]
    # resize pixels to the model size
    face = cv2.resize(face, required_size)
    return face

# %%
new_path = 'C:\\Users\\Lenovo\\Documents\\Github\\Datasets\\LFW-edited'
for person_name in os.listdir(path):
    
    for num, img_name in enumerate(os.listdir(os.path.join(path, person_name))):
        img_path = os.path.join(path, person_name, img_name)
        path_to_write = os.path.join(new_path, person_name)
        
        if os.path.isfile(os.path.join(path_to_write, img_name)):
            continue
            
        img = extract_face(img_path, required_size=IMAGE_SIZE)
        if img is None:
            print(f'----------- NO FACE IN {img_name} -----------')
            continue
        
        if not os.path.exists(path_to_write):
        # Create the directory if it does not exist
            os.makedirs(path_to_write)
        cv2.imwrite(os.path.join(path_to_write, img_name), img)
    print(f'{num+1} images saved in {path_to_write}')

# %% [markdown]
# ### Create the data pipeline

# %%
# create the data input pipeline for train and val dataset
trainTripletGenerator = TripletGenerator(
    datasetPath=TRAIN_DATASET)

valTripletGenerator = TripletGenerator(
    datasetPath=TEST_DATASET)

trainTfDataset = tf.data.Dataset.from_generator(
    generator=trainTripletGenerator.get_next_element,
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
    )
)

valTfDataset = tf.data.Dataset.from_generator(
    generator=valTripletGenerator.get_next_element,
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
    )
)
# Out:
# 1318 folders have more than 1 image
# ----------------------------
# 300 folders have more than 1 image
# ----------------------------

# %%
mapFunction = MapFunction(imageSize=IMAGE_SIZE)

print("[INFO] building the train and validation `tf.data` pipeline...")
trainDs = (trainTfDataset
    .map(mapFunction)
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .prefetch(2)
)
valDs = (valTfDataset
    .map(mapFunction)
    .batch(BATCH_SIZE)
    .prefetch(2)
)
# Out:
# [INFO] building the train and validation `tf.data` pipeline...

# %% [markdown]
# ### Create Model

# %%
def get_embedding_module(imageSize):
    # construct the input layer and pass the inputs through a
    # pre-processing layer
    
    model_path = 'C:\\Users\\Lenovo\\Documents\\Github\\Models and Weights\\keras_models\\resnet50_imagenet.h5'
    
    inputs = keras.Input(IMAGE_SIZE + (3,))
    x = resnet.preprocess_input(inputs)
    
    # fetch the pre-trained resnet 50 model and freeze the weights
    baseCnn = keras.models.load_model(model_path)
    baseCnn.trainable=False
    
    # pass the pre-processed inputs through the base cnn and get the
    # extracted features from the inputs
    extractedFeatures = baseCnn(x)
    # pass the extracted features through a number of trainable layers
    x = layers.GlobalAveragePooling2D()(extractedFeatures)
    x = layers.Dense(units=1024, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(units=256, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(units=128)(x)
    # build the embedding model and return it
    embedding = keras.Model(inputs, outputs, name="embedding")
    return embedding

# %%
def get_siamese_network(imageSize, embeddingModel):
    # build the anchor, positive and negative input layer
    anchorInput = keras.Input(name="anchor", shape=imageSize + (3,))
    positiveInput = keras.Input(name="positive", shape=imageSize + (3,))
    negativeInput = keras.Input(name="negative", shape=imageSize + (3,))
    # embed the anchor, positive and negative images
    anchorEmbedding = embeddingModel(anchorInput)
    positiveEmbedding = embeddingModel(positiveInput)
    negativeEmbedding = embeddingModel(negativeInput)
    # build the siamese network and return it
    siamese_network = keras.Model(
        inputs=[anchorInput, positiveInput, negativeInput],
        outputs=[anchorEmbedding, positiveEmbedding, negativeEmbedding]
    )
    return siamese_network

# %%
class SiameseModel(keras.Model):
    
    def __init__(self, siameseNetwork, margin, lossTracker):
        super().__init__()
        self.siameseNetwork = siameseNetwork
        self.margin = margin
        self.lossTracker = lossTracker
        
    def _compute_distance(self, inputs):
        (anchor, positive, negative) = inputs
        # embed the images using the siamese network
        embeddings = self.siameseNetwork((anchor, positive, negative))
        anchorEmbedding = embeddings[0]
        positiveEmbedding = embeddings[1]
        negativeEmbedding = embeddings[2]
        # calculate the anchor to positive and negative distance
        apDistance = tf.reduce_sum(
            tf.square(anchorEmbedding - positiveEmbedding), axis=-1
        )
        anDistance = tf.reduce_sum(
            tf.square(anchorEmbedding - negativeEmbedding), axis=-1
        )
        
        # return the distances
        return (apDistance, anDistance)
    
    def _compute_loss(self, apDistance, anDistance):
        loss = apDistance - anDistance
        loss = tf.maximum(loss + self.margin, 0.0)
        return loss
        
    def call(self, inputs):
        # compute the distance between the anchor and positive,
        # negative images
        (apDistance, anDistance) = self._compute_distance(inputs)
        return (apDistance, anDistance)
    
    def train_step(self, inputs):
        with tf.GradientTape() as tape:
            # compute the distance between the anchor and positive,
            # negative images
            (apDistance, anDistance) = self._compute_distance(inputs)
            # calculate the loss of the siamese network
            loss = self._compute_loss(apDistance, anDistance)
            
        # compute the gradients and optimize the model
        gradients = tape.gradient(
            loss,
            self.siameseNetwork.trainable_variables)
        self.optimizer.apply_gradients(
            zip(gradients, self.siameseNetwork.trainable_variables)
        )
        # update the metrics and return the loss
        self.lossTracker.update_state(loss)
        return {"loss": self.lossTracker.result()}
    
    def test_step(self, inputs):
        # compute the distance between the anchor and positive,
        # negative images
        (apDistance, anDistance) = self._compute_distance(inputs)
        # calculate the loss of the siamese network
        loss = self._compute_loss(apDistance, anDistance)
        
        # update the metrics and return the loss
        self.lossTracker.update_state(loss)
        return {"loss": self.lossTracker.result()}
    
    @property
    def metrics(self):
        return [self.lossTracker]

# %%
# build the embedding module and the siamese network

embeddingModule = get_embedding_module(imageSize=IMAGE_SIZE)

siameseNetwork =  get_siamese_network(
    imageSize=IMAGE_SIZE,
    embeddingModel=embeddingModule,
)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
siameseNetwork.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  anchor (InputLayer)            [(None, 224, 224, 3  0           []
#                                 )]
#
#  positive (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  negative (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  embedding (Functional)         (None,
ARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.2298 - val_loss: 0.2350
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2215WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.2215 - val_loss: 0.2331
# Epoch 43/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2357WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 28s 963ms/step - loss: 0.2357 - val_loss: 0.2191
# Epoch 44/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2222WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 28s 938ms/step - loss: 0.2222 - val_loss: 0.2146
# Epoch 45/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2280WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 27s 923ms/step - loss: 0.2280 - val_loss: 0.2352
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2115WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 27s 925ms/step - loss: 0.2115 - val_loss: 0.2367
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2209WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 27s 927ms/step - loss: 0.2209 - val_loss: 0.2388
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2357WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 27s 922ms/step - loss: 0.2357 - val_loss: 0.2319
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2209WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 28s 934ms/step - loss: 0.2209 - val_loss: 0.2275
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2358WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 27s 925ms/step - loss: 0.2358 - val_loss: 0.2172

# %% [markdown]
# #### Second try

# %%
def get_embedding_module(imageSize):
    # construct the input layer and pass the inputs through a
    # pre-processing layer
    
    model_path = 'C:\\Users\\Lenovo\\Documents\\Github\\Models and Weights\\keras_models\\resnet50_imagenet.h5'
    
    inputs = keras.Input(IMAGE_SIZE + (3,))
    x = resnet.preprocess_input(inputs)
    
    # fetch the pre-trained resnet 50 model and freeze the weights
    baseCnn = keras.models.load_model(model_path)
    baseCnn.trainable=False
    
    # pass the pre-processed inputs through the base cnn and get the
    # extracted features from the inputs
    extractedFeatures = baseCnn(x)
    # pass the extracted features through a number of trainable layers
    x = layers.Flatten()(extractedFeatures)
    x = layers.Dense(units=1024, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(units=256, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(units=128)(x)
    # build the embedding model and return it
    embedding = keras.Model(inputs, outputs, name="embedding")
    return embedding

# %%
# build the embedding module and the siamese network

embeddingModule = get_embedding_module(imageSize=IMAGE_SIZE)

siameseNetwork =  get_siamese_network(
    imageSize=IMAGE_SIZE,
    embeddingModel=embeddingModule,
)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
#create siamese model instance
siameseModel = SiameseModel(
    siameseNetwork=siameseNetwork,
    margin=1.0,
    lossTracker=keras.metrics.Mean(name="loss"),
)

# %%
# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=0.0001)

# %%
siameseModel.compile(
    optimizer=keras.optimizers.Adam(0.001),
)

# %%
# train and validate the siamese model

result_2 = siameseModel.fit(
    trainDs,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=valDs,
    validation_steps=VALIDATION_STEPS,
    epochs=EPOCHS,
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.8895WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 46s 1s/step - loss: 0.8895 - val_loss: 0.7878 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - ETA: 0s - loss: 0.7282WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 974ms/step - loss: 0.7282 - val_loss: 0.6540 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - ETA: 0s - loss: 0.6453WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 980ms/step - loss: 0.6453 - val_loss: 0.6055 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5931WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 977ms/step - loss: 0.5931 - val_loss: 0.5381 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5502WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 974ms/step - loss: 0.5502 - val_loss: 0.5839 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5373WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.5373 - val_loss: 0.5601 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - ETA: 0s - loss: 0.4883WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 971ms/step - loss: 0.4883 - val_loss: 0.5066 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5104WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 973ms/step - loss: 0.5104 - val_loss: 0.5026 - lr: 0.0010
# Epoch 9/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5207WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 970ms/step - loss: 0.5207 - val_loss: 0.4979 - lr: 0.0010
# Epoch 10/50
# 30/30 [==============================] - ETA: 0s - loss: 0.4882WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 973ms/step - loss: 0.4882 - val_loss: 0.4695 - lr: 0.0010
# Epoch 11/50
# 30/30 [==============================] - ETA: 0s - loss: 0.
50
# 30/30 [==============================] - ETA: 0s - loss: 0.2314WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.2314 - val_loss: 0.2644 - lr: 5.0000e-04
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2596WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 971ms/step - loss: 0.2596 - val_loss: 0.2441 - lr: 5.0000e-04
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2514WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.2514 - val_loss: 0.2350 - lr: 5.0000e-04
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2515WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 967ms/step - loss: 0.2515 - val_loss: 0.2304 - lr: 5.0000e-04
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: 0.2243WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.2243 - val_loss: 0.2415 - lr: 5.0000e-04

# %% [markdown]
# ##### third try

# %%
#create siamese model instance
siameseModel = SiameseModel(
    siameseNetwork=siameseNetwork,
    margin=1.5,
    lossTracker=keras.metrics.Mean(name="loss"),
)

# %%
# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, verbose=1, min_lr=0.00001)

# %%
siameseModel.compile(
    optimizer=keras.optimizers.Adam(0.001),
)

# %%
# train and validate the siamese model

result_3 = siameseModel.fit(
    trainDs,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=valDs,
    validation_steps=VALIDATION_STEPS,
    epochs=EPOCHS,
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - ETA: 0s - loss: 1.3022WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 47s 1s/step - loss: 1.3022 - val_loss: 1.1372 - lr: 0.0010
# Epoch 2/100
# 30/30 [==============================] - ETA: 0s - loss: 1.0394WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 1.0394 - val_loss: 1.0855 - lr: 0.0010
# Epoch 3/100
# 30/30 [==============================] - ETA: 0s - loss: 0.9500WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 967ms/step - loss: 0.9500 - val_loss: 1.0966 - lr: 0.0010
# Epoch 4/100
# 30/30 [==============================] - ETA: 0s - loss: 0.8250WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.8250 - val_loss: 1.0536 - lr: 0.0010
# Epoch 5/100
# 30/30 [==============================] - ETA: 0s - loss: 0.7882WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 967ms/step - loss: 0.7882 - val_loss: 0.9630 - lr: 0.0010
# Epoch 6/100
# 30/30 [==============================] - ETA: 0s - loss: 0.8003WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.8003 - val_loss: 0.9857 - lr: 0.0010
# Epoch 7/100
# 30/30 [==============================] - ETA: 0s - loss: 0.7215WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.7215 - val_loss: 0.9607 - lr: 0.0010
# Epoch 8/100
# 30/30 [==============================] - ETA: 0s - loss: 0.7438WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.7438 - val_loss: 0.9361 - lr: 0.0010
# Epoch 9/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6680WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 976ms/step - loss: 0.6680 - val_loss: 0.8896 - lr: 0.0010
# Epoch 10/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6798WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.6798 - val_loss: 1.0568 - lr: 0.0010
# Epoch 11/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6702WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 970ms/step - loss: 0.6702 - val_loss: 0.9646 - lr: 0.0010
# Epoch 12/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6195WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.6195 - val_loss: 1.0669 - lr: 0.0010
# Epoch 13/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6462WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.6462 - val_loss: 0.9827 - lr: 0.0010
# Epoch 14/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6541WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.6541 - val_loss: 0.9574 - lr: 0.0010
# Epoch 15/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6362WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.6362 - val_loss: 0.7878 - lr: 8.0000e-04
# Epoch 16/100
# 30/30 [==============================] - ETA: 0s - loss: 0.5736WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.5736 - val_loss: 0.8736 - lr: 8.0000e-04
# Epoch 17/100
# 30/30 [==============================] - ETA: 0s - loss: 0.5594WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 967ms/step - loss: 0.5594 - val_loss: 0.9712 - lr: 8.0000e-04
# Epoch 18/100
# 30/30 [==============================] - ETA: 0s - loss: 0.5813WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 968ms/step - loss: 0.5813 - val_loss: 0.8982 - lr: 8.0000e-04
# Epoch 19/100
# 30/30 [==============================] - ETA: 0s - loss: 0.5247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 971ms/step - loss: 0
100
# 30/30 [==============================] - ETA: 0s - loss: 0.2303WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.2303 - val_loss: 0.7251 - lr: 1.3422e-04
# Epoch 82/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1977WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 974ms/step - loss: 0.1977 - val_loss: 0.7119 - lr: 1.0737e-04
# Epoch 83/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2069WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 971ms/step - loss: 0.2069 - val_loss: 0.6878 - lr: 1.0737e-04
# Epoch 84/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2265WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 970ms/step - loss: 0.2265 - val_loss: 0.7700 - lr: 1.0737e-04
# Epoch 85/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1936WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 978ms/step - loss: 0.1936 - val_loss: 0.6964 - lr: 1.0737e-04
# Epoch 86/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2386WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# 30/30 [==============================] - 29s 976ms/step - loss: 0.2386 - val_loss: 0.7161 - lr: 1.0737e-04
# Epoch 87/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2069WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 975ms/step - loss: 0.2069 - val_loss: 0.7232 - lr: 8.5899e-05
# Epoch 88/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2158WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 973ms/step - loss: 0.2158 - val_loss: 0.6976 - lr: 8.5899e-05
# Epoch 89/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1935WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 973ms/step - loss: 0.1935 - val_loss: 0.7703 - lr: 8.5899e-05
# Epoch 90/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2071WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 977ms/step - loss: 0.2071 - val_loss: 0.6064 - lr: 8.5899e-05
# Epoch 91/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2008WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 973ms/step - loss: 0.2008 - val_loss: 0.7232 - lr: 8.5899e-05
# Epoch 92/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2409WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.2409 - val_loss: 0.6979 - lr: 8.5899e-05
# Epoch 93/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2174WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.2174 - val_loss: 0.7274 - lr: 8.5899e-05
# Epoch 94/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1699WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 972ms/step - loss: 0.1699 - val_loss: 0.7138 - lr: 8.5899e-05
# Epoch 95/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2598WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# 30/30 [==============================] - 29s 971ms/step - loss: 0.2598 - val_loss: 0.6488 - lr: 8.5899e-05
# Epoch 96/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1998WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 967ms/step - loss: 0.1998 - val_loss: 0.7353 - lr: 6.8719e-05
# Epoch 97/100
# 30/30 [==============================] - ETA: 0s - loss: 0.2236WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 967ms/step - loss: 0.2236 - val_loss: 0.7140 - lr: 6.8719e-05
# Epoch 98/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1912WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 969ms/step - loss: 0.1912 - val_loss: 0.7060 - lr: 6.8719e-05
# Epoch 99/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1774WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 30/30 [==============================] - 29s 974ms/step - loss: 0.1774 - val_loss: 0.6901 - lr: 6.8719e-05
# Epoch 100/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1797WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# 30/30 [==============================] - 29s 974ms/step - loss: 0.1797 - val_loss: 0.7638 - lr: 6.8719e-05

# %% [markdown]
# ### Save model

# %%
#model name for saving and loading
model_name = 'siamese_network_2'

# %%
OUTPUT_PATH = '.\model'
MODEL_PATH = os.path.join(OUTPUT_PATH, model_name)
print(MODEL_PATH)
# Out:
# .\model\siamese_network_2

# %%
# check if the output directory exists, if it doesn't, then
# create it
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)
# save the siamese network to disk
modelPath = MODEL_PATH
print(f"[INFO] saving the siamese network to {modelPath}...")
keras.models.save_model(
    model=siameseModel.siameseNetwork,
    filepath=modelPath,
    include_optimizer=False,
)
# Out:
# [INFO] saving the siamese network to .\model\siamese_network_3...
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\model\siamese_network_3\assets
# INFO:tensorflow:Assets written to: .\model\siamese_network_3\assets

# %% [markdown]
# ### Prediction

# %%
# create the data input pipeline for test dataset
print("[INFO] building the test generator...")
testTripletGenerator = TripletGenerator(
    datasetPath=TEST_DATASET)
print("[INFO] building the test `tf.data` dataset...")
testTfDataset = tf.data.Dataset.from_generator(
    generator=testTripletGenerator.get_next_element,
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
    )
)
mapFunction = MapFunction(imageSize=IMAGE_SIZE)
testDs = (testTfDataset
    .map(mapFunction)
    .batch(10)
    .prefetch(2)
)


# load the siamese network from disk and build the siamese model
modelPath = MODEL_PATH
print(f"[INFO] loading the siamese network from {modelPath}...")
siameseNetwork = keras.models.load_model(filepath=modelPath)
siameseModel = SiameseModel(
    siameseNetwork=siameseNetwork,
    margin=1.0,
    lossTracker=keras.metrics.Mean(name="loss"),
)
# load the test data
(anchor, positive, negative) = next(iter(testDs))
(apDistance, anDistance) = siameseModel((anchor, positive, negative))
plt.figure(figsize=(10, 25))
rows = 10
for row in range(rows):
    plt.subplot(rows, 3, row * 3 + 1)
    plt.imshow(anchor[row])
    plt.axis("off")
    plt.title("Anchor image")
    plt.subplot(rows, 3, row * 3 + 2)
    plt.imshow(positive[row])
    plt.axis("off")
    plt.title(f"Positive distance: {apDistance[row]:0.2f}")
    plt.subplot(rows, 3, row * 3 + 3)
    plt.imshow(negative[row])
    plt.axis("off")
    plt.title(f"Negative distance: {anDistance[row]:0.2f}")
# Out:
# [INFO] building the test generator...
# 300 folders have more than 1 image
# ----------------------------
# [INFO] building the test `tf.data` dataset...
# [INFO] loading the siamese network from .\model\siamese_network_2...
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
layers_mean = []
for layer in siameseModel.get_weights():
    layers_mean.append(layer.mean())

# %%
plt.plot(layers_mean)

# %%
positive_distances = []
negative_distances = []
for i in range(30):
    (anchor, positive, negative) = next(iter(testDs))
    (apDistance, anDistance) = siameseModel((anchor, positive, negative))
    
    positive_distances.append(apDistance.numpy().tolist())
    negative_distances.append(anDistance.numpy().tolist())
    
positive_distances = tf.concat(positive_distances, axis=0)
negative_distances = tf.concat(negative_distances, axis=0)

# %%
plt.hist(positive_distances, bins=50, alpha=0.7, label='Positive Distance')
plt.hist(negative_distances, bins=50, alpha=0.7, label='Negative Distance')
plt.legend()

# %% [markdown]
# ### Save the single-output model version

# %%
inputs = tf.keras.Input(shape=IMAGE_SIZE + (3,))
outputs = siameseNetwork.get_layer('embedding')(inputs)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
# Load pre-trained weights
model.set_weights(siameseNetwork.get_weights())

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  embedding (Functional)      (None, 128)               127044352
#
# =================================================================
# Total params: 127,044,352
# Trainable params: 103,453,568
# Non-trainable params: 23,590,784
# _________________________________________________________________

# %%
single_output_model_name = 'single_output_model_2'
MODEL_PATH = os.path.join(OUTPUT_PATH, single_output_model_name)
print(MODEL_PATH)
# Out:
# .\model\single_output_model_2

# %%
# create it
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)
# save the siamese network to disk
modelPath = MODEL_PATH
print(f"[INFO] saving the siamese network to {modelPath}...")
keras.models.save_model(
    model=model,
    filepath=modelPath,
    include_optimizer=False,
)
# Out:
# [INFO] saving the siamese network to .\model\single_output_model_2...
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\model\single_output_model_2\assets
# INFO:tensorflow:Assets written to: .\model\single_output_model_2\assets
